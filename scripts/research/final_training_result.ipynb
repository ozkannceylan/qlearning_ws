# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/ozkan/Desktop/rl_ws/src/scripts/research'

# %%
data_path = "../Data/final_output.csv"
df=pd.read_csv(data_path)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 data_path = "../Data/final_output.csv"
# ----> 2 df=pd.read_csv(data_path)
#       3 df
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#bring the row where max avg_reward is max
df[df['avg_reward'] == df['avg_reward'].max()]
df
# Out:
#              type     agent                                   scenario  alpha  \
# 0   epsilongreedy    random                        Scenario_1_Moderate    0.5
# 1   epsilongreedy    random  Scenario_2_Fast_Learning_High_Exploration    0.7
# 2   epsilongreedy    random   Scenario_3_Fast_Learning_Low_Exploration    0.7
# 3   epsilongreedy    random  Scenario_4_Slow_Learning_High_Exploration    0.3
# 4   epsilongreedy    random   Scenario_5_Slow_Learning_Low_Exploration    0.2
# 5   epsilongreedy  constant                        Scenario_1_Moderate    0.5
# 6   epsilongreedy  constant  Scenario_2_Fast_Learning_High_Exploration    0.7
# 7   epsilongreedy  constant   Scenario_3_Fast_Learning_Low_Exploration    0.7
# 8   epsilongreedy  constant  Scenario_4_Slow_Learning_High_Exploration    0.3
# 9   epsilongreedy  constant   Scenario_5_Slow_Learning_Low_Exploration    0.2
# 10        softmax    random                        Scenario_1_Moderate    0.5
# ...
